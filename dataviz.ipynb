# %%
from IPython.display import Video
import cv2
from PIL import Image
import numpy as np
import ffmpeg
import os
import json
import hashlib
import subprocess
from datetime import datetime
from pathlib import Path
import exiftool

# %%
def process_video(
    input_path: str,
    output_path: str,
    target_width: int,
    target_height: int,
    start_time: float | None = None,
    duration: float | None = None,
    fps: int | float | None = None,
) -> None:
    """
    Process a video: adjust resolution (with letterboxing/pillarboxing), FPS, start offset, and duration.

    :param input_path: Path to the source video file.
    :param output_path: Path for the exported video file.
    :param target_width: Target canvas width in pixels.
    :param target_height: Target canvas height in pixels.
    :param start_time: Start offset in seconds (optional).
    :param duration: Total length to extract in seconds from start_time (optional).
    :param fps: Desired output frame rate (optional).
    """
    input_kwargs = {}

    # Fast input seeking
    if start_time is not None:
        input_kwargs["ss"] = start_time

    # Trim duration from start_time
    if duration is not None:
        input_kwargs["t"] = duration

    stream = ffmpeg.input(input_path, **input_kwargs)

    # Separate video and audio streams
    video = stream.video

    # Scale maintaining aspect ratio, then pad with black bars
    video = video.filter(
        "scale",
        w=target_width,
        h=target_height,
        force_original_aspect_ratio="decrease",
    ).filter(
        "pad",
        w=target_width,
        h=target_height,
        x="(ow-iw)/2",
        y="(oh-ih)/2",
        color="black",
    )

    # Apply frame rate filter if specified
    if fps is not None:
        video = video.filter("fps", fps=fps)

    output_kwargs = {
        "vcodec": "libx264",
        "acodec": "aac",
        "pix_fmt": "yuv420p",
    }

    output = ffmpeg.output(video, output_path, **output_kwargs)

    # Execute
    ffmpeg.run(output, overwrite_output=True)

# %%
import os
import re
import json
import hashlib
import subprocess
from datetime import datetime
from pathlib import Path
import exiftool

# Assuming process_video is defined or imported:
# from your_module import process_video


def extract_datetime_from_filename(filename: str) -> str | None:
    """Extracts timestamp from DJI pattern: DJI_YYYYMMDDHHMMSS_..."""
    # Matches patterns like DJI_20251103105307_0001_D
    match = re.search(r"(\d{4})(\d{2})(\d{2})(\d{2})(\d{2})(\d{2})", filename)
    if match:
        year, month, day, hour, minute, second = match.groups()
        return f"{year}{month}{day}_{hour}{minute}{second}"
    return None


def get_recording_datetime_and_metadata(file_path: Path) -> tuple[str, dict]:
    """Extracts true recording time and all deep metadata using ExifTool, fallback regex, and FFprobe."""
    resolved_path = str(file_path.resolve())
    stat = file_path.stat()
    
    metadata = {
        "file_system": {
            "filename": file_path.name,
            "original_path": resolved_path,
            "size_bytes": stat.st_size,
            "filesystem_mtime": datetime.fromtimestamp(stat.st_mtime).isoformat(),
            "extension": file_path.suffix.lower()
        },
        "drone_and_exif_metadata": {},
        "ffprobe_streams": {}
    }

    # 1. Read deep metadata via ExifTool
    try:
        with exiftool.ExifToolHelper() as et:
            raw_exif = et.get_metadata(resolved_path)
            if raw_exif:
                metadata["drone_and_exif_metadata"] = raw_exif[0]
    except Exception as e:
        metadata["drone_and_exif_metadata"] = {"error": str(e)}

    # 2. Read streams via FFprobe
    cmd = [
        "ffprobe",
        "-v", "quiet",
        "-print_format", "json",
        "-show_format",
        "-show_streams",
        resolved_path
    ]
    try:
        result = subprocess.run(cmd, capture_output=True, text=True, check=True)
        metadata["ffprobe_streams"] = json.loads(result.stdout)
    except Exception as e:
        metadata["ffprobe_streams"] = {"error": str(e)}

    # 3. Determine the TRUE recording timestamp
    exif = metadata["drone_and_exif_metadata"]
    date_str = None
    
    # Check EXIF/QuickTime internal date tags (prioritize tags that have creation time)
    candidate_keys = [
        "QuickTime:CreationDate",
        "QuickTime:CreateDate",
        "EXIF:DateTimeOriginal",
        "XMP:CreateDate",
        "XMP:DateTimeOriginal"
    ]
    
    for key in candidate_keys:
        raw_val = exif.get(key)
        if raw_val and isinstance(raw_val, str) and not raw_val.startswith("0000"):
            # Clean format "2025:11:03 10:53:07" or "2025:11:03 10:53:07-04:00"
            clean_date = raw_val.split("+")[0].split("-")[0].strip() if "+" in raw_val or ("-" in raw_val and raw_val.count("-") == 1) else raw_val
            clean_date = re.sub(r"[^\d]", "", clean_date)[:14] # YYYYMMDDhhmmss
            if len(clean_date) == 14:
                date_str = f"{clean_date[:8]}_{clean_date[8:]}"
                break

    # Fallback A: Extract from filename (e.g. DJI_20251103105307_0001_D)
    if not date_str:
        date_str = extract_datetime_from_filename(file_path.name)

    # Fallback B: Last modified time on disk
    if not date_str:
        date_str = datetime.fromtimestamp(stat.st_mtime).strftime("%Y%m%d_%H%M%S")

    metadata["recording_timestamp"] = date_str
    return date_str, metadata


def generate_unique_folder_name(file_path: Path, recording_timestamp: str) -> str:
    """Combines recording timestamp with short path-hash to guarantee uniqueness."""
    hash_str = hashlib.sha256(str(file_path.resolve()).encode("utf-8")).hexdigest()[:8]
    return f"{recording_timestamp}_{hash_str}"


def process_video_dataset(input_dir: str, output_base_dir: str) -> None:
    """Recursively traverses input_dir, ignores non-videos, extracts real metadata, and runs process_video."""
    input_folder = Path(input_dir)
    output_folder = Path(output_base_dir)

    valid_extensions = {".mp4", ".mov", ".avi", ".mkv", ".webm", ".ts"}
    
    # Use rglob to recursively search all subdirectories
    video_files = [
        f for f in input_folder.rglob("*") 
        if f.is_file() and f.suffix.lower() in valid_extensions
    ]

    print(f"Found {len(video_files)} video(s) to process.")

    for video_path in video_files:
        # 1. Extract metadata and true recording date
        recording_date, full_metadata = get_recording_datetime_and_metadata(video_path)

        # 2. Create unique output directory based on recording date + hash
        unique_folder_name = generate_unique_folder_name(video_path, recording_date)
        dest_dir = output_folder / unique_folder_name
        dest_dir.mkdir(parents=True, exist_ok=True)

        # 3. Define output paths
        output_video_path = dest_dir / f"processed_{video_path.name}"
        metadata_path = dest_dir / "metadata.json"

        # 4. Save metadata.json
        with open(metadata_path, "w", encoding="utf-8") as f:
            json.dump(full_metadata, f, indent=4, ensure_ascii=False)

        # 5. Execute processing
        print(f"\n[+] Processing: {video_path.relative_to(input_folder)}")
        print(f"    Recorded on: {recording_date} -> Output: {dest_dir.name}")
        
        process_video(
            input_path=str(video_path),
            output_path=str(output_video_path),
            target_width=1024,
            target_height=1024,
            start_time=0.0,
            duration=31.0,
            fps=15
        )

# %%
process_video_dataset("./dataset/unprocessed", "./dataset/processed")
# Out:
# Found 8 video(s) to process.
#
# [+] Processing: DJI_0720.MP4
#     Recorded on: 20260526_133321 -> Output: 20260526_133321_48134879
# ffmpeg version 8.0.1-3ubuntu2 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15 (Ubuntu 15.2.0-13ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-pocketsphinx --disable-libcaca --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libjxl --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-librsvg --enable-shared
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset/unprocessed/DJI_0720.MP4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     creation_time   : 2026-05-26T13:33:21.000000Z
#     encoder         : Lavf56.15.102
#   Duration: 00:00:22.02, start: 0.000000, bitrate: 156213 kb/s
#   Stream #0:0[0x1](und): Video: hevc (Main) (hvc1 / 0x31637668), yuv420p(tv), 5472x3078, 156211 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2026-05-26T13:33:21.000000Z
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (hevc) -> scale:default
#   fps:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5fc40cdee480] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5fc40cdee480] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5fc40cdee480] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'dataset/processed/20260526_133321_48134879/processed_DJI_0720.MP4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1024x1024, q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x5fc40cdcca00] video:5801KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.072298%
# frame=  330 fps=7.4 q=-1.0 Lsize=    5806KiB time=00:00:21.86 bitrate=2175.0kbits/s speed=0.491x elapsed=0:00:44.50
# [libx264 @ 0x5fc40cdee480] frame I:2     Avg QP:14.83  size: 71878
# [libx264 @ 0x5fc40cdee480] frame P:154   Avg QP:16.98  size: 30582
# [libx264 @ 0x5fc40cdee480] frame B:174   Avg QP:19.90  size:  6245
# [libx264 @ 0x5fc40cdee480] consecutive B-frames: 25.2%  9.7% 11.8% 53.3%
# [libx264 @ 0x5fc40cdee480] mb I  I16..4: 45.2% 28.0% 26.8%
# [libx264 @ 0x5fc40cdee480] mb P  I16..4:  0.7%  1.1%  0.5%  P16..4: 23.3% 17.1% 11.0%  0.0%  0.0%    skip:46.2%
# [libx264 @ 0x5fc40cdee480] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 28.9%  3.8%  1.1%  direct: 3.4%  skip:62.8%  L0:32.1% L1:49.6% BI:18.3%
# [libx264 @ 0x5fc40cdee480] 8x8 transform intra:41.0% inter:47.5%
# [libx264 @ 0x5fc40cdee480] coded y,uvDC,uvAC intra: 55.2% 41.1% 17.3% inter: 19.9% 11.4% 0.4%
# [libx264 @ 0x5fc40cdee480] i16 v,h,dc,p: 58% 34%  5%  3%
# [libx264 @ 0x5fc40cdee480] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10%  8% 27%  8%  9%  7%  8%  7% 15%
# [libx264 @ 0x5fc40cdee480] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 12% 20% 10% 10%  8%  8%  8%  9%
# [libx264 @ 0x5fc40cdee480] i8c dc,h,v,p: 61% 27% 10%  2%
# [libx264 @ 0x5fc40cdee480] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5fc40cdee480] ref P L0: 69.9% 20.1%  7.3%  2.7%
# [libx264 @ 0x5fc40cdee480] ref B L0: 98.3%  1.4%  0.3%
# [libx264 @ 0x5fc40cdee480] ref B L1: 99.4%  0.6%
# [libx264 @ 0x5fc40cdee480] kb/s:2160.00
# [+] Processing: .ipynb_checkpoints/DJI_0720-checkpoint.MP4
#     Recorded on: 20260526_133321 -> Output: 20260526_133321_c0d252ef
# ffmpeg version 8.0.1-3ubuntu2 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15 (Ubuntu 15.2.0-13ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-pocketsphinx --disable-libcaca --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libjxl --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-librsvg --enable-shared
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset/unprocessed/.ipynb_checkpoints/DJI_0720-checkpoint.MP4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     creation_time   : 2026-05-26T13:33:21.000000Z
#     encoder         : Lavf56.15.102
#   Duration: 00:00:22.02, start: 0.000000, bitrate: 156213 kb/s
#   Stream #0:0[0x1](und): Video: hevc (Main) (hvc1 / 0x31637668), yuv420p(tv), 5472x3078, 156211 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2026-05-26T13:33:21.000000Z
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (hevc) -> scale:default
#   fps:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e1c09304c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e1c09304c0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x55e1c09304c0] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'dataset/processed/20260526_133321_c0d252ef/processed_DJI_0720-checkpoint.MP4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1024x1024, q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x55e1c090ea40] video:5801KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.072298%
# frame=  330 fps=7.4 q=-1.0 Lsize=    5806KiB time=00:00:21.86 bitrate=2175.0kbits/s speed=0.491x elapsed=0:00:44.51
# [libx264 @ 0x55e1c09304c0] frame I:2     Avg QP:14.83  size: 71878
# [libx264 @ 0x55e1c09304c0] frame P:154   Avg QP:16.98  size: 30582
# [libx264 @ 0x55e1c09304c0] frame B:174   Avg QP:19.90  size:  6245
# [libx264 @ 0x55e1c09304c0] consecutive B-frames: 25.2%  9.7% 11.8% 53.3%
# [libx264 @ 0x55e1c09304c0] mb I  I16..4: 45.2% 28.0% 26.8%
# [libx264 @ 0x55e1c09304c0] mb P  I16..4:  0.7%  1.1%  0.5%  P16..4: 23.3% 17.1% 11.0%  0.0%  0.0%    skip:46.2%
# [libx264 @ 0x55e1c09304c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 28.9%  3.8%  1.1%  direct: 3.4%  skip:62.8%  L0:32.1% L1:49.6% BI:18.3%
# [libx264 @ 0x55e1c09304c0] 8x8 transform intra:41.0% inter:47.5%
# [libx264 @ 0x55e1c09304c0] coded y,uvDC,uvAC intra: 55.2% 41.1% 17.3% inter: 19.9% 11.4% 0.4%
# [libx264 @ 0x55e1c09304c0] i16 v,h,dc,p: 58% 34%  5%  3%
# [libx264 @ 0x55e1c09304c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10%  8% 27%  8%  9%  7%  8%  7% 15%
# [libx264 @ 0x55e1c09304c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 12% 20% 10% 10%  8%  8%  8%  9%
# [libx264 @ 0x55e1c09304c0] i8c dc,h,v,p: 61% 27% 10%  2%
# [libx264 @ 0x55e1c09304c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e1c09304c0] ref P L0: 69.9% 20.1%  7.3%  2.7%
# [libx264 @ 0x55e1c09304c0] ref B L0: 98.3%  1.4%  0.3%
# [libx264 @ 0x55e1c09304c0] ref B L1: 99.4%  0.6%
# [libx264 @ 0x55e1c09304c0] kb/s:2160.00
# [+] Processing: myairbridge-Vt1EbS3JhOo/DJI_20251215180333_0089_D - Delfines chilenos.MP4
#     Recorded on: 20260813_233250 -> Output: 20260813_233250_ee3d47e3
# ffmpeg version 8.0.1-3ubuntu2 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15 (Ubuntu 15.2.0-13ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-pocketsphinx --disable-libcaca --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libjxl --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-librsvg --enable-shared
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset/unprocessed/myairbridge-Vt1EbS3JhOo/DJI_20251215180333_0089_D - Delfines chilenos.MP4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2026-08-13T23:32:50.000000Z
#   Duration: 00:00:37.50, start: 0.000000, bitrate: 130920 kb/s
#   Stream #0:0[0x1](und): Video: hevc (Main 10) (hvc1 / 0x31637668), yuv420p10le(tv, bt709), 3840x2160, 129964 kb/s, 59.94 fps, 59.94 tbr, 60k tbn (default)
#     Metadata:
#       creation_time   : 2026-08-13T23:32:50.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (hevc) -> scale:default
#   fps:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5d2190cbfec0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5d2190cbfec0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5d2190cbfec0] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'dataset/processed/20260813_233250_ee3d47e3/processed_DJI_20251215180333_0089_D - Delfines chilenos.MP4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x1024, q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x5d2190cae9c0] video:22585KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024603%
# frame=  465 fps=6.8 q=-1.0 Lsize=   22591KiB time=00:00:30.86 bitrate=5995.5kbits/s speed=0.451x elapsed=0:01:08.39
# [libx264 @ 0x5d2190cbfec0] frame I:4     Avg QP:15.74  size: 82516
# [libx264 @ 0x5d2190cbfec0] frame P:218   Avg QP:19.13  size: 56922
# [libx264 @ 0x5d2190cbfec0] frame B:243   Avg QP:22.35  size: 42746
# [libx264 @ 0x5d2190cbfec0] consecutive B-frames: 30.1%  0.4%  0.6% 68.8%
# [libx264 @ 0x5d2190cbfec0] mb I  I16..4: 44.3% 27.6% 28.1%
# [libx264 @ 0x5d2190cbfec0] mb P  I16..4:  0.6% 15.7% 11.1%  P16..4:  9.8% 12.6%  7.0%  0.0%  0.0%    skip:43.2%
# [libx264 @ 0x5d2190cbfec0] mb B  I16..4:  0.0%  5.5%  5.4%  B16..8: 15.1% 13.0%  7.6%  direct: 8.7%  skip:44.8%  L0:36.1% L1:32.6% BI:31.4%
# [libx264 @ 0x5d2190cbfec0] 8x8 transform intra:54.0% inter:46.4%
# [libx264 @ 0x5d2190cbfec0] coded y,uvDC,uvAC intra: 93.8% 41.6% 22.9% inter: 35.5% 12.1% 0.6%
# [libx264 @ 0x5d2190cbfec0] i16 v,h,dc,p: 63% 25%  6%  6%
# [libx264 @ 0x5d2190cbfec0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 11% 13%  8% 14% 11% 13%  8% 13%
# [libx264 @ 0x5d2190cbfec0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 14% 16%  9% 12%  9% 11%  7% 10%
# [libx264 @ 0x5d2190cbfec0] i8c dc,h,v,p: 73% 14% 10%  3%
# [libx264 @ 0x5d2190cbfec0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5d2190cbfec0] ref P L0: 58.6% 25.5%  9.4%  6.5%
# [libx264 @ 0x5d2190cbfec0] ref B L0: 93.5%  4.0%  2.5%
# [libx264 @ 0x5d2190cbfec0] ref B L1: 99.0%  1.0%
# [libx264 @ 0x5d2190cbfec0] kb/s:5968.09
# [+] Processing: myairbridge-Vt1EbS3JhOo/DJI_20260521154041_0101_D - Delfines australes.MP4
#     Recorded on: 20260813_213529 -> Output: 20260813_213529_7f994a2f
# ffmpeg version 8.0.1-3ubuntu2 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15 (Ubuntu 15.2.0-13ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-pocketsphinx --disable-libcaca --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libjxl --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-librsvg --enable-shared
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset/unprocessed/myairbridge-Vt1EbS3JhOo/DJI_20260521154041_0101_D - Delfines australes.MP4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2026-08-13T21:35:29.000000Z
#   Duration: 00:00:31.65, start: 0.000000, bitrate: 130197 kb/s
#   Stream #0:0[0x1](und): Video: hevc (Main 10) (hvc1 / 0x31637668), yuv420p10le(tv, bt709), 3840x2160, 130089 kb/s, 59.94 fps, 59.94 tbr, 60k tbn (default)
#     Metadata:
#       creation_time   : 2026-08-13T21:35:29.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (hevc) -> scale:default
#   fps:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x62046b21fcc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x62046b21fcc0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x62046b21fcc0] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'dataset/processed/20260813_213529_7f994a2f/processed_DJI_20260521154041_0101_D - Delfines australes.MP4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x1024, q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x62046b207fc0] video:1776KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.200496%
# frame=  465 fps=6.6 q=-1.0 Lsize=    1779KiB time=00:00:30.86 bitrate= 472.3kbits/s speed=0.437x elapsed=0:01:10.70
# [libx264 @ 0x62046b21fcc0] frame I:3     Avg QP:12.46  size:  9481
# [libx264 @ 0x62046b21fcc0] frame P:382   Avg QP:14.98  size:  4214
# [libx264 @ 0x62046b21fcc0] frame B:80    Avg QP:17.87  size:  2246
# [libx264 @ 0x62046b21fcc0] consecutive B-frames: 77.0%  0.0%  0.6% 22.4%
# [libx264 @ 0x62046b21fcc0] mb I  I16..4: 64.0% 28.4%  7.6%
# [libx264 @ 0x62046b21fcc0] mb P  I16..4:  0.4%  0.2%  0.0%  P16..4: 28.1%  3.3%  4.3%  0.0%  0.0%    skip:63.6%
# [libx264 @ 0x62046b21fcc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 24.7%  0.3%  0.0%  direct: 1.1%  skip:73.7%  L0:38.1% L1:61.2% BI: 0.7%
# [libx264 @ 0x62046b21fcc0] 8x8 transform intra:31.4% inter:93.4%
# [libx264 @ 0x62046b21fcc0] coded y,uvDC,uvAC intra: 17.2% 31.2% 10.2% inter: 6.3% 18.6% 0.0%
# [libx264 @ 0x62046b21fcc0] i16 v,h,dc,p: 53% 41%  3%  3%
# [libx264 @ 0x62046b21fcc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 12% 43%  3%  3%  2%  4%  1% 11%
# [libx264 @ 0x62046b21fcc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 15% 33%  3%  3%  2%  2%  2%  2%
# [libx264 @ 0x62046b21fcc0] i8c dc,h,v,p: 56% 36%  8%  1%
# [libx264 @ 0x62046b21fcc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x62046b21fcc0] ref P L0: 62.6%  2.8% 23.7% 10.9%
# [libx264 @ 0x62046b21fcc0] ref B L0: 88.8%  9.2%  1.9%
# [libx264 @ 0x62046b21fcc0] ref B L1: 93.5%  6.5%
# [libx264 @ 0x62046b21fcc0] kb/s:469.11
# [+] Processing: myairbridge-Vt1EbS3JhOo/DJI_20251106122608_0028_D - Delfines oscuros.MP4
#     Recorded on: 20260813_212652 -> Output: 20260813_212652_52055251
# ffmpeg version 8.0.1-3ubuntu2 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15 (Ubuntu 15.2.0-13ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-pocketsphinx --disable-libcaca --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libjxl --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-librsvg --enable-shared
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset/unprocessed/myairbridge-Vt1EbS3JhOo/DJI_20251106122608_0028_D - Delfines oscuros.MP4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2026-08-13T21:26:52.000000Z
#   Duration: 00:00:25.50, start: 0.000000, bitrate: 132111 kb/s
#   Stream #0:0[0x1](und): Video: hevc (Main 10) (hvc1 / 0x31637668), yuv420p10le(tv, bt709), 3840x2160, 129944 kb/s, 59.94 fps, 59.94 tbr, 60k tbn (default)
#     Metadata:
#       creation_time   : 2026-08-13T21:26:52.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (hevc) -> scale:default
#   fps:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5c5d4b4cbd40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5c5d4b4cbd40] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5c5d4b4cbd40] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'dataset/processed/20260813_212652_52055251/processed_DJI_20251106122608_0028_D - Delfines oscuros.MP4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x1024, q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x5c5d4b4b7e40] video:4428KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.121690%
# frame=  382 fps=6.8 q=-1.0 Lsize=    4434KiB time=00:00:25.33 bitrate=1433.7kbits/s speed=0.45x elapsed=0:00:56.33
# [libx264 @ 0x5c5d4b4cbd40] frame I:2     Avg QP:14.06  size: 35391
# [libx264 @ 0x5c5d4b4cbd40] frame P:96    Avg QP:15.99  size: 23196
# [libx264 @ 0x5c5d4b4cbd40] frame B:284   Avg QP:19.56  size:  7874
# [libx264 @ 0x5c5d4b4cbd40] consecutive B-frames:  0.8%  0.0%  0.8% 98.4%
# [libx264 @ 0x5c5d4b4cbd40] mb I  I16..4: 46.5% 42.4% 11.1%
# [libx264 @ 0x5c5d4b4cbd40] mb P  I16..4:  0.5%  3.5%  2.2%  P16..4: 26.0% 11.1%  6.8%  0.0%  0.0%    skip:49.9%
# [libx264 @ 0x5c5d4b4cbd40] mb B  I16..4:  0.0%  0.1%  0.2%  B16..8: 33.4%  3.0%  0.8%  direct: 2.0%  skip:60.4%  L0:41.8% L1:52.7% BI: 5.4%
# [libx264 @ 0x5c5d4b4cbd40] 8x8 transform intra:49.9% inter:64.3%
# [libx264 @ 0x5c5d4b4cbd40] coded y,uvDC,uvAC intra: 70.6% 43.4% 15.3% inter: 14.4% 8.5% 0.1%
# [libx264 @ 0x5c5d4b4cbd40] i16 v,h,dc,p: 63% 24%  8%  6%
# [libx264 @ 0x5c5d4b4cbd40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5% 22% 23%  5%  6%  2% 15%  2% 20%
# [libx264 @ 0x5c5d4b4cbd40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 16% 40%  4%  6%  3%  7%  2%  5%
# [libx264 @ 0x5c5d4b4cbd40] i8c dc,h,v,p: 67% 23%  8%  1%
# [libx264 @ 0x5c5d4b4cbd40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5c5d4b4cbd40] ref P L0: 56.0% 15.7% 20.5%  7.9%
# [libx264 @ 0x5c5d4b4cbd40] ref B L0: 91.1%  6.9%  2.0%
# [libx264 @ 0x5c5d4b4cbd40] ref B L1: 96.3%  3.7%
# [libx264 @ 0x5c5d4b4cbd40] kb/s:1424.23
# [+] Processing: myairbridge-Vt1EbS3JhOo/DJI_0008 - Deflines australes.MOV
#     Recorded on: 20260813_234103 -> Output: 20260813_234103_218e5d30
# ffmpeg version 8.0.1-3ubuntu2 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15 (Ubuntu 15.2.0-13ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-pocketsphinx --disable-libcaca --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libjxl --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-librsvg --enable-shared
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset/unprocessed/myairbridge-Vt1EbS3JhOo/DJI_0008 - Deflines australes.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2026-08-13T23:41:03.000000Z
#     location        : -39.954929-73.592422+17.400
#     location-{    : -39.954929-73.592422+17.400
#     comment         : DE=D-Cinelike, Mode=M, DSW=0001
#   Duration: 00:00:16.40, start: 0.000000, bitrate: 110605 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 4096x2160 [SAR 1:1 DAR 256:135], 99958 kb/s, 59.94 fps, 59.94 tbr, 60k tbn (default)
#     Metadata:
#       creation_time   : 2026-08-13T23:41:03.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC encoder
# Stream mapping:
#   Stream #0:0 (h264) -> scale:default
#   fps:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x64cd49111680] using SAR=1/1
# [libx264 @ 0x64cd49111680] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x64cd49111680] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x64cd49111680] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mov, to 'dataset/processed/20260813_234103_218e5d30/processed_DJI_0008 - Deflines australes.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     comment         : DE=D-Cinelike, Mode=M, DSW=0001
#     location        : -39.954929-73.592422+17.400
#     location-{    : -39.954929-73.592422+17.400
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mov @ 0x64cd491136c0] video:2935KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.125435%
# frame=  246 fps= 25 q=-1.0 Lsize=    2939KiB time=00:00:16.26 bitrate=1480.0kbits/s speed=1.63x elapsed=0:00:09.95
# [libx264 @ 0x64cd49111680] frame I:1     Avg QP:15.53  size: 31754
# [libx264 @ 0x64cd49111680] frame P:82    Avg QP:17.78  size: 19510
# [libx264 @ 0x64cd49111680] frame B:163   Avg QP:20.82  size:  8425
# [libx264 @ 0x64cd49111680] consecutive B-frames:  9.8%  4.1%  4.9% 81.3%
# [libx264 @ 0x64cd49111680] mb I  I16..4: 52.8% 34.4% 12.8%
# [libx264 @ 0x64cd49111680] mb P  I16..4:  1.7%  5.7%  2.5%  P16..4: 28.0%  8.5%  4.9%  0.0%  0.0%    skip:48.7%
# [libx264 @ 0x64cd49111680] mb B  I16..4:  0.4%  0.3%  0.3%  B16..8: 28.9%  3.9%  1.1%  direct: 2.7%  skip:62.5%  L0:44.0% L1:45.9% BI:10.0%
# [libx264 @ 0x64cd49111680] 8x8 transform intra:50.6% inter:70.1%
# [libx264 @ 0x64cd49111680] coded y,uvDC,uvAC intra: 61.5% 41.9% 1.5% inter: 14.8% 13.4% 0.0%
# [libx264 @ 0x64cd49111680] i16 v,h,dc,p: 53% 20%  7% 20%
# [libx264 @ 0x64cd49111680] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7% 16% 26%  6% 10%  4% 18%  4%  9%
# [libx264 @ 0x64cd49111680] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 18% 27%  7%  8%  5% 10%  4%  6%
# [libx264 @ 0x64cd49111680] i8c dc,h,v,p: 67% 23%  9%  1%
# [libx264 @ 0x64cd49111680] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x64cd49111680] ref P L0: 61.1% 13.1% 16.6%  9.2%
# [libx264 @ 0x64cd49111680] ref B L0: 93.1%  5.2%  1.7%
# [libx264 @ 0x64cd49111680] ref B L1: 98.5%  1.5%
# [libx264 @ 0x64cd49111680] kb/s:1465.79
# [+] Processing: myairbridge-Vt1EbS3JhOo/DJI_20251103105307_0001_D - Delfines oscuros y Lisos 2.mp4
#     Recorded on: 20260814_004529 -> Output: 20260814_004529_01db9042
# ffmpeg version 8.0.1-3ubuntu2 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15 (Ubuntu 15.2.0-13ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-pocketsphinx --disable-libcaca --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libjxl --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-librsvg --enable-shared
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset/unprocessed/myairbridge-Vt1EbS3JhOo/DJI_20251103105307_0001_D - Delfines oscuros y Lisos 2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2026-08-14T00:45:29.000000Z
#   Duration: 00:00:37.90, start: 0.000000, bitrate: 10391 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 3840x2160, 10064 kb/s, 59.94 fps, 59.94 tbr, 60k tbn (default)
#     Metadata:
#       creation_time   : 2026-08-14T00:45:29.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2026-08-14T00:45:29.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> scale:default
#   fps:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5e509b4def40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5e509b4def40] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5e509b4def40] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'dataset/processed/20260814_004529_01db9042/processed_DJI_20251103105307_0001_D - Delfines oscuros y Lisos 2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x1024, q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x5e509b4dde40] video:10414KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.058011%
# frame=  465 fps= 37 q=-1.0 Lsize=   10420KiB time=00:00:30.86 bitrate=2765.3kbits/s speed=2.44x elapsed=0:00:12.64
# [libx264 @ 0x5e509b4def40] frame I:2     Avg QP:15.81  size: 69198
# [libx264 @ 0x5e509b4def40] frame P:171   Avg QP:17.78  size: 37993
# [libx264 @ 0x5e509b4def40] frame B:292   Avg QP:21.55  size: 13793
# [libx264 @ 0x5e509b4def40] consecutive B-frames: 15.5%  1.3%  3.2% 80.0%
# [libx264 @ 0x5e509b4def40] mb I  I16..4: 44.4% 39.8% 15.7%
# [libx264 @ 0x5e509b4def40] mb P  I16..4:  0.7% 11.0%  3.5%  P16..4: 19.1% 13.9%  7.2%  0.0%  0.0%    skip:44.6%
# [libx264 @ 0x5e509b4def40] mb B  I16..4:  0.0%  0.2%  0.0%  B16..8: 25.6%  7.0%  2.6%  direct: 8.8%  skip:55.7%  L0:31.6% L1:36.4% BI:32.1%
# [libx264 @ 0x5e509b4def40] 8x8 transform intra:70.2% inter:56.1%
# [libx264 @ 0x5e509b4def40] coded y,uvDC,uvAC intra: 88.5% 49.6% 21.6% inter: 26.6% 10.0% 0.2%
# [libx264 @ 0x5e509b4def40] i16 v,h,dc,p: 52% 39%  3%  6%
# [libx264 @ 0x5e509b4def40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  9% 14% 17%  7% 11%  9% 13%  7% 12%
# [libx264 @ 0x5e509b4def40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 15% 16%  7% 13% 10% 12%  6%  9%
# [libx264 @ 0x5e509b4def40] i8c dc,h,v,p: 64% 22% 13%  2%
# [libx264 @ 0x5e509b4def40] Weighted P-Frames: Y:9.4% UV:2.3%
# [libx264 @ 0x5e509b4def40] ref P L0: 58.5% 28.1%  8.8%  4.2%  0.4%
# [libx264 @ 0x5e509b4def40] ref B L0: 98.7%  0.9%  0.4%
# [libx264 @ 0x5e509b4def40] ref B L1: 99.9%  0.1%
# [libx264 @ 0x5e509b4def40] kb/s:2751.68
# [+] Processing: myairbridge-Vt1EbS3JhOo/DJI_0005 - Delfines chilenos.MOV
#     Recorded on: 20260813_233811 -> Output: 20260813_233811_b384f7f9
# ffmpeg version 8.0.1-3ubuntu2 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15 (Ubuntu 15.2.0-13ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-pocketsphinx --disable-libcaca --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libjxl --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-librsvg --enable-shared
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset/unprocessed/myairbridge-Vt1EbS3JhOo/DJI_0005 - Delfines chilenos.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2026-08-13T23:38:11.000000Z
#     location        : -46.377707-73.675860+63.600
#     location-{    : -46.377707-73.675860+63.600
#     comment         : 0.91.142
#   Duration: 00:00:16.09, start: 0.000000, bitrate: 60282 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 4096x2160 [SAR 1:1 DAR 256:135], 60093 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2026-08-13T23:38:11.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Dji AVC encoder
# Stream mapping:
#   Stream #0:0 (h264) -> scale:default
#   fps:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x6106e5600380] using SAR=1/1
# [libx264 @ 0x6106e5600380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x6106e5600380] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x6106e5600380] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mov, to 'dataset/processed/20260813_233811_b384f7f9/processed_DJI_0005 - Delfines chilenos.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     comment         : 0.91.142
#     location        : -46.377707-73.675860+63.600
#     location-{    : -46.377707-73.675860+63.600
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mov @ 0x6106e56056c0] video:3348KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.110244%
# frame=  241 fps= 42 q=-1.0 Lsize=    3352KiB time=00:00:15.93 bitrate=1723.5kbits/s speed=2.81x elapsed=0:00:05.67
# [libx264 @ 0x6106e5600380] frame I:2     Avg QP:15.18  size: 40144
# [libx264 @ 0x6106e5600380] frame P:84    Avg QP:18.71  size: 23485
# [libx264 @ 0x6106e5600380] frame B:155   Avg QP:21.59  size:  8871
# [libx264 @ 0x6106e5600380] consecutive B-frames: 14.1%  0.0%  1.2% 84.6%
# [libx264 @ 0x6106e5600380] mb I  I16..4: 48.5% 40.8% 10.7%
# [libx264 @ 0x6106e5600380] mb P  I16..4:  0.5%  8.8%  1.4%  P16..4: 22.8% 12.0%  5.6%  0.0%  0.0%    skip:49.0%
# [libx264 @ 0x6106e5600380] mb B  I16..4:  0.5%  0.2%  0.0%  B16..8: 29.3%  3.1%  0.9%  direct: 4.9%  skip:61.1%  L0:42.3% L1:47.6% BI:10.1%
# [libx264 @ 0x6106e5600380] 8x8 transform intra:70.2% inter:63.8%
# [libx264 @ 0x6106e5600380] coded y,uvDC,uvAC intra: 78.1% 17.9% 0.1% inter: 20.7% 4.2% 0.0%
# [libx264 @ 0x6106e5600380] i16 v,h,dc,p: 90%  6%  2%  1%
# [libx264 @ 0x6106e5600380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 12% 21%  9% 11% 10%  9%  7% 13%
# [libx264 @ 0x6106e5600380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 13% 18%  8% 15% 12% 10%  6%  8%
# [libx264 @ 0x6106e5600380] i8c dc,h,v,p: 80% 12%  8%  0%
# [libx264 @ 0x6106e5600380] Weighted P-Frames: Y:6.0% UV:0.0%
# [libx264 @ 0x6106e5600380] ref P L0: 60.0% 18.5% 12.2%  8.9%  0.5%
# [libx264 @ 0x6106e5600380] ref B L0: 95.5%  3.1%  1.4%
# [libx264 @ 0x6106e5600380] ref B L1: 99.2%  0.8%
# [libx264 @ 0x6106e5600380] kb/s:1706.94

# %% [raw]
# video_path = "dataset/unprocessed/myairbridge-Vt1EbS3JhOo/DJI_20260521154041_0101_D - Delfines australes.MP4"
# output_path = "dataset/test.mp4"
# #Video(video_path, embed=True, width=640)

# %% [raw]
# process_video(
#     input_path= video_path ,
#     output_path= output_path,
#     target_width= 1024,
#     target_height= 1024,
#     start_time= 0.0,
#     duration= 31.0,
#     fps = 15
# )

# %% [raw]
# Video(output_path, embed=True, width=640)
